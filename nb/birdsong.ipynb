# %%
import tensorflow as tf
import tensorflow_io as tfio
import matplotlib.pyplot as plt
from pathlib import Path

# %%
audio_dir = Path("/home/guilhem/cours/birdsong-app/raw_dataset")
spectro_dir = Path("/home/guilhem/cours/birdsong-app/dataset")

spectro_dir.mkdir(parents=True, exist_ok=True)

def process_audio_file(audio_path):
    try:
        audio = tfio.audio.AudioIOTensor(str(audio_path))
        audio_tensor = tf.squeeze(audio[100:], axis=[-1])

        audio_tensor = tf.cast(audio_tensor, tf.float32) / 32768.0

        spectrogram = tfio.audio.spectrogram(
            audio_tensor, nfft=512, window=512, stride=256
        )

        plt.figure(figsize=(10, 4))
        plt.imshow(
            tf.math.log(spectrogram + 1e-6).numpy().T,
            aspect='auto',
            origin='lower',
            cmap='magma'
        )
        plt.axis('off')

        relative_path = audio_path.relative_to(audio_dir)
        output_path = spectro_dir / relative_path.with_suffix('.png')
        output_path.parent.mkdir(parents=True, exist_ok=True)

        plt.savefig(output_path, bbox_inches='tight', pad_inches=0)
        plt.close()
        print(f"✅ Sauvé : {output_path}")
    except Exception as e:
        print(f"❌ Échec pour {audio_path} : {e}")

all_audio_files = list(audio_dir.rglob("*.ogg"))

print(f"🔍 {len(all_audio_files)} fichiers trouvés.")

for audio_path in all_audio_files:
    process_audio_file(audio_path)
# Out:
# 🔍 145 fichiers trouvés.
# 2025-05-02 14:43:08.381273: I tensorflow_io/core/kernels/cpu_check.cc:128] Your CPU supports instructions that this TensorFlow IO binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# 2025-05-02 14:43:08.451931: W tensorflow_io/core/kernels/audio_video_mp3_kernels.cc:271] libmp3lame.so.0 or lame functions are not available
# 2025-05-02 14:43:08.898266: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-02 14:43:08.898699: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC748857.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC235919.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC375878.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC205521.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC132731.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC294900.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC622853.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC375876.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC205894.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC700635.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC364582.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC605853.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC247387.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC195161.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC316216.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC342701.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC490712.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC352745.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC444334.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC375877.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC205583.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC490710.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC367167.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/bagwea1/XC440519.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC467122.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC606253.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC531557.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC585802.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC363501.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC363504.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC756300.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC616997.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC128013.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC363503.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC379322.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC639039.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC467121.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC363502.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/abethr1/XC432639.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC235933.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC234729.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC690369.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC235700.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC703473.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC316030.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC704478.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC473926.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC434328.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC704569.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC155155.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC289569.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC233773.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC469902.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/easmog1/XC266004.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC371368.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC345087.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC699732.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC536672.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601823.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601818.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC604709.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC240874.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC753984.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC373991.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC431766.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601816.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601819.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC244607.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601817.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC234628.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC614624.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC244606.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC467119.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC426180.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601815.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601814.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC444649.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC131907.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC240872.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC337023.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601822.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC244609.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601813.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC667275.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601821.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/darbar1/XC601820.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC116120.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC124332.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC236131.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC444570.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC155184.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC122400.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC396381.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC555846.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC115976.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC546580.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC124658.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC236130.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC116121.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC123955.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC236129.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC352740.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC754034.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC158714.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC753194.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC703341.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC444489.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC434140.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC236132.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC124659.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC163715.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC156989.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC124657.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC124145.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC116119.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC124144.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC289528.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC155156.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC388652.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/cabgre1/XC289459.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC267912.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC529126.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC509609.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC474458.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC447027.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC687331.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC348306.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC354694.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC371225.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC371194.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC293554.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC687332.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC322388.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC445355.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC512852.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC529125.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC687329.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC746540.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC267910.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC267911.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC746120.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC746121.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC748247.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC746541.png
# ✅ Sauvé : /home/guilhem/cours/birdsong-app/dataset/bird_spectrogram/fatrav1/XC293487.png

# %%
dataset_dir = '/home/guilhem/cours/birdsong-app/dataset/bird_spectrogram'

training_set = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    image_size=(775, 308),  
    batch_size=32,
    label_mode='int',
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="training",
)

validation_set = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    image_size=(775, 308),  
    batch_size=32,
    label_mode='int',
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="validation",
)
# Out:
# Found 145 files belonging to 6 classes.
# Using 116 files for training.
# Found 145 files belonging to 6 classes.
# Using 29 files for validation.
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))> <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = training_set.prefetch(buffer_size=AUTOTUNE)
val_ds = validation_set.prefetch(buffer_size=AUTOTUNE)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation=None, input_shape=(775, 308, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    tf.keras.layers.Conv2D(64, (3, 3), activation=None),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    tf.keras.layers.Conv2D(128, (3, 3), activation=None),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    
    tf.keras.layers.GlobalAveragePooling2D(),
    
    tf.keras.layers.Dense(128, activation=None),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dropout(0.3),
    
    tf.keras.layers.Dense(6, activation='softmax')
])
# Out:
# /home/guilhem/cours/birdsong-app/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    training_set,
    validation_data=validation_set,
    epochs=30
)
# Out:
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.2492 - loss: 2.0144 - val_accuracy: 0.2414 - val_loss: 2.5738
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.3881 - loss: 1.5008 - val_accuracy: 0.2069 - val_loss: 2.7269
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5946 - loss: 1.2620 - val_accuracy: 0.2069 - val_loss: 2.9647
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4664 - loss: 1.2807 - val_accuracy: 0.2069 - val_loss: 3.0870
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5436 - loss: 1.2477 - val_accuracy: 0.2414 - val_loss: 3.3473
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5279 - loss: 1.2497 - val_accuracy: 0.2069 - val_loss: 3.3721
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4833 - loss: 1.2718 - val_accuracy: 0.0690 - val_loss: 2.9980
# Epoch 8/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5971 - loss: 1.1211 - val_accuracy: 0.1379 - val_loss: 2.6827
# Epoch 9/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5864 - loss: 1.1217 - val_accuracy: 0.1724 - val_loss: 2.3838
# Epoch 10/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5824 - loss: 1.1349 - val_accuracy: 0.2759 - val_loss: 2.1397
# Epoch 11/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6400 - loss: 1.0619 - val_accuracy: 0.2414 - val_loss: 2.0926
# Epoch 12/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6145 - loss: 1.0902 - val_accuracy: 0.2414 - val_loss: 2.0761
# Epoch 13/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.5581 - loss: 1.0864 - val_accuracy: 0.3103 - val_loss: 2.1352
# Epoch 14/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.6929 - loss: 0.9010 - val_accuracy: 0.3448 - val_loss: 2.0483
# Epoch 15/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7255 - loss: 0.8933 - val_accuracy: 0.3103 - val_loss: 2.0207
# Epoch 16/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.6406 - loss: 1.0108 - val_accuracy: 0.2069 - val_loss: 2.1733
# Epoch 17/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.7037 - loss: 0.8585 - val_accuracy: 0.2759 - val_loss: 2.1599
# Epoch 18/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6947 - loss: 0.8722 - val_accuracy: 0.2414 - val_loss: 1.9926
# Epoch 19/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6985 - loss: 0.8046 - val_accuracy: 0.2759 - val_loss: 1.9062
# Epoch 20/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6783 - loss: 0.9040 - val_accuracy: 0.1724 - val_loss: 1.9388
# Epoch 21/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7812 - loss: 0.7416 - val_accuracy: 0.2414 - val_loss: 1.9067
# Epoch 22/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6153 - loss: 0.8609 - val_accuracy: 0.2759 - val_loss: 1.8539
# Epoch 23/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7431 - loss: 0.8214 - val_accuracy: 0.2069 - val_loss: 2.0091
# Epoch 24/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6804 - loss: 0.7996 - val_accuracy: 0.2414 - val_loss: 2.0924
# Epoch 25/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6318 - loss: 0.9238 - val_accuracy: 0.2414 - val_loss: 1.9715
# Epoch 26/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7400 - loss: 0.7667 - val_accuracy: 0.2069 - val_loss: 1.9263
# Epoch 27/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.6727 - loss: 0.8293 - val_accuracy: 0.2414 - val_loss: 2.2125
# Epoch 28/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7846 - loss: 0.7040 - val_accuracy: 0.2069 - val_loss: 2.0204
# Epoch 29/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8000 - loss: 0.7072 - val_accuracy: 0.2069 - val_loss: 1.9796
# Epoch 30/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7050 - loss: 0.7362 - val_accuracy: 0.2069 - val_loss: 2.3026
